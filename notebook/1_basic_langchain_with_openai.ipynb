# %%
### Load Env Variables

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
### Connect with Google Gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
res = llm.invoke("Who is pm of India ?")

# %%
print(res.content)
# Out:
# [{'type': 'text', 'text': 'The current Prime Minister of India is **Narendra Modi**. He has been in office since May 2014.', 'extras': {'signature': '...'}}]

# %%
#### Static Prompts
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-3.6-flash")

# %%
prompts = [
    ("system", "You are a Java Developer"),  ###(type, ) "System", "AI", "user"
    ("user", "How to sort the array.")
]
res = llm.invoke(prompts)
print(res.content)
# Out:
# [{'type': 'text', 'text': 'In Java, the most efficient and standard way to sort an array is using the **`java.util.Arrays`** class. \n\nHere are the different ways to sort an array depending on your specific use case:\n\n---\n\n### 1. Sorting Primitive Arrays in Ascending Order\nTo sort numbers or characters in increasing order, use `Arrays.sort()`.\n\n```java\nimport java.util.Arrays;\n\npublic class SortExample {\n    public static void main(String[] args) {\n        int[] numbers = {5, 2, 8, 1, 9, 4};\n        \n        // Sorts array in ascending order\n        Arrays.sort(numbers);\n        \n        System.out.println(Arrays.toString(numbers)); \n        // Output: [1, 2, 4, 5, 8, 9]\n    }\n}\n```\n\n---\n\n### 2. Sorting String/Object Arrays (Alphabetical Order)\nStrings are sorted alphabetically (lexicographically).\n\n```java\nimport java.util.Arrays;\n\npublic class SortExample {\n    public static void main(String[] args) {\n        String[] fruits = {"Banana", "Apple", "Mango", "Cherry"};\n        \n        Arrays.sort(fruits);\n        \n        System.out.println(Arrays.toString(fruits)); \n        // Output: [Apple, Banana, Cherry, Mango]\n    }\n}\n```\n\n---\n\n### 3. Sorting in Descending Order\nTo sort in reverse order, use `Collections.reverseOrder()`. \n> **Note:** This requires Object wrapper types (e.g., `Integer[]` instead of `int[]`).\n\n```java\nimport java.util.Arrays;\nimport java.util.Collections;\n\npublic class SortExample {\n    public static void main(String[] args) {\n        Integer[] numbers = {5, 2, 8, 1, 9, 4}; // Must use Integer, not int\n        \n        // Sorts array in descending order\n        Arrays.sort(numbers, Collections.reverseOrder());\n        \n        System.out.println(Arrays.toString(numbers)); \n        // Output: [9, 8, 5, 4, 2, 1]\n    }\n}\n```\n\n---\n\n### 4. Sorting a Sub-array (Part of an Array)\nYou can sort a specific range within an array by specifying the start index (inclusive) and end index (exclusive).\n\n```java\nimport java.util.Arrays;\n\npublic class SortExample {\n    public static void main(String[] args) {\n        int[] numbers = {9, 7, 3, 1, 5, 2};\n        \n        // Sorts only index 1 to 4 (elements 7, 3, 1)\n        Arrays.sort(numbers, 1, 4);\n        \n        System.out.println(Arrays.toString(numbers)); \n        // Output: [9, 1, 3, 7, 5, 2]\n    }\n}\n```\n\n---\n\n### 5. Sorting Custom Objects (Using `Comparator`)\nIf you have an array of custom objects (e.g., `Employee`, `Student`), you can use a Lambda expression with `Comparator`.\n\n```java\nimport java.util.Arrays;\nimport java.util.Comparator;\n\nclass Employee {\n    String name;\n    int salary;\n\n    Employee(String name, int salary) {\n        this.name = name;\n        this.salary = salary;\n    }\n\n    @Override\n    public String toString() {\n        return name + " (" + salary + ")";\n    }\n}\n\npublic class SortExample {\n    public static void main(String[] args) {\n        Employee[] employees = {\n            new Employee("Alice", 70000),\n            new Employee("Bob", 50000),\n            new Employee("Charlie", 60000)\n        };\n\n        // Sort by salary (ascending)\n        Arrays.sort(employees, Comparator.comparingInt(emp -> emp.salary));\n\n        System.out.println(Arrays.toString(employees));\n        // Output: [Bob (50000), Charlie (60000), Alice (70000)]\n    }\n}\n```\n\n---\n\n### 6. Sorting Large Arrays (Parallel Sort)\nFor very large arrays (millions of elements), Java 8 introduced `Arrays.parallelSort()`, which uses multi-threading to speed up the sorting process.\n\n```java\nimport java.util.Arrays;\n\npublic class SortExample {\n    public static void main(String[] args) {\n        int[] largeArray = { /* millions of items */ };\n        \n        // Uses Fork/Join framework for parallel sorting\n        Arrays.parallelSort(largeArray); \n    }\n}\n```\n\n---\n\n### Performance under the hood:\n* **Primitive Arrays:** `Arrays.sort()` use ...
